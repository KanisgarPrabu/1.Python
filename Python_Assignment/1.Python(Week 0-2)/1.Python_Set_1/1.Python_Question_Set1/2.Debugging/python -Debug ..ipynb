# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)
# Out:
#   Cell In[14], line 3
#     for i in range(5)
#     ^
# IndentationError: unexpected indent

# %%
#Indentation missing and : is missing. 
#Correct code
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3 a = 10
#       4 b = "5"
# ----> 5 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Cant able to do addition operatior or concatenation for a integer and String datatype.
#Both has to be same datatype. either both int or str

a = 10
b = "5"
print (a + int(b))
print(str(a) + b)
# Out:
# 15
# 105

# %% [raw]
# #3.What is the issue in this Python snippet?
#
#  def add_numbers(a, b)
#     return a + b

# %%
#Indentation is wrong and : is missing for the function

def add_number(a,b):
    return a + b

print(add_number(5,3))
# Out:
# 8

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])
# Out:
#   Cell In[23], line 3
#     numbers = [1, 2, 3, 4]
#     ^
# IndentationError: unexpected indent

# %%
#Indentation is wrong and List starts with Index 0 , so it has 3 index for 4 values. 
#Since print(numbers[4]) will throw error for the index out of range
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"
# Out:
# Hello, World!

# %%
#Wrong Print Syntax
print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
# Any number is not divisble by zero. use any number apart from zero . Example

for i in range (1 ,10): #apart from zero other number works
    x = 5 / i
    print(x)
# Out:
# 5.0
# 2.5
# 1.6666666666666667
# 1.25
# 1.0
# 0.8333333333333334
# 0.7142857142857143
# 0.625
# 0.5555555555555556

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
#name variable is commented and wrong concatenation
name = "Alice"
age = 25
print("Name: " + name, "Age: " , age)
# Out:
# Name: Alice Age:  25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#range(start,stop,step) -> Here Step is -1 so from start it will decrease one number and it never comes in the range.

#Correct code

for i in range(1 , 10 , 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")
# Out:
#   Cell In[45], line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# "=" is a assignment operator for assigning values , "==" is the conditional operator
x = 10
if (x ==5):
    print("x is 5")
else:
    print("x is not 5")
# Out:
# x is not 5

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)
# Out:
#   Cell In[48], line 3
#     def greet(name)
#                    ^
# SyntaxError: expected ':'

# %%
# : is missing in the above code
def greet(name):
    print("Hello, " + name)

greet("Kanisgar")
# Out:
# Hello, Kanisgar
