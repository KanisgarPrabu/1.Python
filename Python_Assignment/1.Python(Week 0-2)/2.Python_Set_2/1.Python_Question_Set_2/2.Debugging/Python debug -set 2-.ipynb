# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #1.Find the error in the following Python code:
#       2 import math
# ----> 3 print(Math.sqrt(16))
#
# NameError: name 'Math' is not defined

# %%
#Math is not the right library it is case sensitive

import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 7
#       4     print(x)
#       6 x = 10
# ----> 7 my_function()
#
# Cell In[3], line 3, in my_function()
#       2 def my_function():
# ----> 3     x += 5
#       4     print(x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
#Here x inside my function is a local variable, my_function doesnt have any argument . We have to pass this x as an Argument
def my_function(x):
    x += 5
    print(x)

x = 10
my_function(x)
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")
# Out:
#   Cell In[5], line 2
#     if x = 10:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
x = 5
if (x == 10): # "=" is  the assignment variable where "==" is used to check the condition
    print("x is 10")
else:
    print("x is not 10")
# Out:
# x is not 10

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())
# Out:
# None

# %%
#Sort is a imbuilt function of list and it directly overwrite the list since list is mutuable. Sort returns None but after sort print(numbers will give the sorted result
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))
# Out:
# None

# %%
#no return statement is there
def square(n):
    return n*n

print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #6.
#       2 my_tuple = (1, 2, 3)
# ----> 3 my_tuple[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Tuple is immutable in phython , so you cant add , insert or modify any value to a tuple unlike list

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 name = "Alice"
#       3 age = 25
# ----> 4 print("My name is %s and I am %d years old" % (name))
#
# TypeError: not enough arguments for format string

# %%
#In the print statement for %d the age should have been passed along with the name parameter
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#is keyword is used to compare only the memory that is associated with the object. so use "==" symbol or make the variables
# to point the same memoery of the other variable

a = [1, 2, 3]
b = [1, 2, 3]
if a ==b:
    print("Lists are equal")

a = [1 , 2, 3]
b = a
if a is b:
    print("Lists are equal")
# Out:
# Lists are equal
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
#range usually has (start , stop , incrementor) Here start is greater than stop and Incremental condition not met
for i in range(5, 1 , -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 3
#       1 #10.
#       2 student = {"name": "John", "age": 20}
# ----> 3 print(student[0])
#
# KeyError: 0

# %%
#In key value dictionary we cant call the dict value by the index but with the name

student = {"name": "John", "age": 20}
print(student.get("name"))
# Out:
# John
