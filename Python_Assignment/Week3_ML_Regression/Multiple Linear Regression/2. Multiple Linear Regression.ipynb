# %%
#Profit Prediction using Mutliple Input incl Categorical inputs

# %%
import pandas as pd

# %%
dataset = pd.read_csv("50_Startups.csv")
dataset

# %%
#Doing One Hot Encoding because the dataset has Categorical Col called State and it has Nominal values
dataset = pd.get_dummies(dataset,dtype = int,drop_first=True)
dataset

# %%
dataset.columns.drop('Profit')
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida',
#        'State_New York'],
#       dtype='object')

# %%
independent = dataset[['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida',
       'State_New York']]
independent

# %%
dependent = dataset[['Profit']]
dependent

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent , test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
model = regressor.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
#sample Predicton
predict_out = model.predict([[100000,50000,400000,1,0]])
predict_out
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[135866.70882247]])

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
print(r_score)
# Out:
# 0.9358680970046243

# %%
# Just finding the weight and bias of this model inputs
weight = regressor.coef_
print(weight)
bias = regressor.intercept_
print(bias)
# Out:
# [[7.90840255e-01 3.01968165e-02 3.10148566e-02 4.63028992e+02
#   3.04799573e+02]]
# [42403.87087053]

# %%
import pickle
filename = "multiple_linear_regression.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
model = pickle.load(open(filename,'rb'))
model.predict([[100000,50000,400000,1,0]])
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[135866.70882247]])
