# %%
from MultipleFunctions import MultipleFunctionsClass

# %%
MultipleFunctionsClass.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
MultipleFunctionsClass.OddEven()
# Out:
# Enter a number 12415132
# 12415132 is Even number

# %%
MultipleFunctionsClass.Elegible()
# Out:
# Your Gender fEmAle
# Your age 22
# ELIGIBLE

# %%
MultipleFunctionsClass.percentage()
# Out:
# Subject1= 89
# Subject2= 96
# Subject3= 98
# Subject4= 95
# Subject5= 98
# Total : 476
# Percentage : 95.19999999999999

# %%
MultipleFunctionsClass.triangle()
# Out:
# Height: 10
# Breadth: 5
# Area formula: (Height*Breadth)/2
# Area of Triangle: 25.0
# Height1: 10
# Height2: 14
# Breadth: 20
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triange: 44
