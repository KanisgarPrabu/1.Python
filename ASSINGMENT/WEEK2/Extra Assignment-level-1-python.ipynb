# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name = input("Enter your institute name? :")
# Out:
# Enter your institute name? : HOPE AI

# %%
name = input("Enter your name:")
age = input("Enter your age:")
schl_name = input("Enter your school name:")
degree = input("Enter you degree:")
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru School
# Enter you degree: B.E CSE

# %%
a = 43
b = 34
print("a=",a)
print("b=",b)
print("add=",a+b)
# Out:
# a= 43
# b= 34
# add= 77

# %%
a = 43
b = 34
print("a=",a)
print("b=",b)
print("sub=",a-b)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
a = 63
b = 97
print("a=",a)
print("b=",b)
print("mul=",a*b)
# Out:
# a= 63
# b= 97
# mul= 6111

# %%
a = 76
b = 31
print("a=",a)
print("b=",b)
print("Float Div=",a/b)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
import math
a = 76
b = 31
print("a=",a)
print("b=",b)
print("Floor Div=",math.floor(a/b))
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
a = 76
b = 31
print("a=",a)
print("b=",b)
print("Modulo=",a%b)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
a = 4
b = 4
print("Power=",pow(a,b))
# Out:
# Power= 256
