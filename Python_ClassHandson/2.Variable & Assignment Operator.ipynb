# %%
num1 = 10
num2 = 20
add = num1 + num2
print(add)
print("The num1 is" ,num1,"The num2 is",num2,"The addition is",add)
print(f"The num1  is {num1} and the num2 is {num2} and the addition is {add} ")
# Out:
# 30
# The num1 is 10 The num2 is 20 The addition is 30
# The num1  is 10 and the num2 is 20 and the addition is 30

# %%
num1 = int(input("Enter the number 1"))
num2 = float(input("Enter the number 2"))
add = num1 + num2 
print(f"The addition of {num1} and {num2} is {add} and datatype of {add} is {type(add)}")
# Out:
# Enter the number 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 num1 = int(input("Enter the number 1"))
#       2 num2 = float(input("Enter the number 2"))
#       3 add = num1 + num2
#
# ValueError: invalid literal for int() with base 10: ''
