# %%
list = [16 , 57, 85, 90]

for i in list:
    print(i,type(i),type(list))
# Out:
# 16 <class 'int'> <class 'list'>
# 57 <class 'int'> <class 'list'>
# 85 <class 'int'> <class 'list'>
# 90 <class 'int'> <class 'list'>

# %%
def ageCategory(list):
    for age in list:
        if (age >= 18):
            print('Adult')
        elif (age < 18):
            print('Minor')
        else:
            print('Invalid Age')

ageCategory(list)
# Out:
# Minor
# Adult
# Adult
# Adult
